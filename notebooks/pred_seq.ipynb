# %% [markdown]
# # Predicted Sequence Analysis
#
# Starter notebook for predicted-sequence visualizations.

# %%
from hypnose_analysis.utils.pred_seq_utils import (
    first_odor_poke_duration,
    last_odor_poke_time,
    poke_time_all_pos,
    response_time,
    trial_poke_duration,
 )

# %%
# Example: last-odor poke time boxplots
last_odor_poke_time(subjids=[25], dates=(20250701, 20250731))

# %%
# Example: trial poke duration boxplots
trial_poke_duration(subjids=[25], dates=(20250701, 20250731))

# %%
# Example: first-odor poke duration
first_odor_poke_duration(subjids=[25], dates=(20250701, 20250731))

# %%
# Example: poke duration pooled across positions
poke_time_all_pos(subjids=[25], dates=(20250701, 20250731))

# %%
# Example: response time by odor sequence
response_time(subjids=[25], dates=(20250701, 20250731))
